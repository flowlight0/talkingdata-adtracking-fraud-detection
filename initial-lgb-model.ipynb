# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import lightgbm as lgb
import gc

# %%
# %time train = pd.read_feather('data/train.feather')
# Out:
# CPU times: user 1.5 s, sys: 1.18 s, total: 2.68 s
# Wall time: 2.68 s

# %%
# %time test = pd.read_feather('data/test.feather')
# Out:
# CPU times: user 124 ms, sys: 92 ms, total: 216 ms
# Wall time: 216 ms

# %%
len_train = len(train)
print('The initial size of the train set is', len_train)
print('Binding the training and test set together...')
train=train.append(test)
# Out:
# The initial size of the train set is 184903890
# Binding the training and test set together...

# %%
del test
gc.collect()
# Out:
# 3342

# %%
print("Creating new time features: 'hour' and 'day'...")
train['hour'] = pd.to_datetime(train.click_time).dt.hour.astype('uint8')
train['day'] = pd.to_datetime(train.click_time).dt.day.astype('uint8')
# Out:
# Creating new time features: 'hour' and 'day'...

# %%
gc.collect()
# Out:
# 14

# %%
print("Creating new count features: 'n_channels', 'ip_app_count', 'ip_app_os_count'...")

print('Computing the number of channels associated with ')
print('a given IP address within each hour...')
n_chans = train[['ip','day','hour','channel']].groupby(by=['ip','day',
          'hour'])[['channel']].count().reset_index().rename(columns={'channel': 'n_channels'})

print('Merging the channels data with the main data set...')
train = train.merge(n_chans, on=['ip','day','hour'], how='left')
del n_chans
gc.collect()

print('Computing the number of channels associated with ')
print('a given IP address and app...')
n_chans = train[['ip','app', 'channel']].groupby(by=['ip', 
          'app'])[['channel']].count().reset_index().rename(columns={'channel': 'ip_app_count'})
          
print('Merging the channels data with the main data set...')
train = train.merge(n_chans, on=['ip','app'], how='left')
del n_chans
gc.collect()

print('Computing the number of channels associated with ')
print('a given IP address, app, and os...')
n_chans = train[['ip','app', 'os', 'channel']].groupby(by=['ip', 'app', 
          'os'])[['channel']].count().reset_index().rename(columns={'channel': 'ip_app_os_count'})
          
print('Merging the channels data with the main data set...')       
train = train.merge(n_chans, on=['ip','app', 'os'], how='left')
del n_chans
gc.collect()
# Out:
# Creating new count features: 'n_channels', 'ip_app_count', 'ip_app_os_count'...
# Computing the number of channels associated with
# a given IP address within each hour...
# Merging the channels data with the main data set...
# Computing the number of channels associated with
# a given IP address and app...
# Merging the channels data with the main data set...
# Computing the number of channels associated with
# a given IP address, app, and os...
# Merging the channels data with the main data set...
# 117

# %%
print("Adjusting the data types of the new count features... ")
train.info()
train['n_channels'] = train['n_channels'].astype('uint16')
train['ip_app_count'] = train['ip_app_count'].astype('uint16')
train['ip_app_os_count'] = train['ip_app_os_count'].astype('uint16')
# Out:
# Adjusting the data types of the new count features...
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 203694359 entries, 0 to 203694358
# Data columns (total 14 columns):
# app                uint16
# attributed_time    datetime64[ns]
# channel            uint16
# click_id           float64
# click_time         datetime64[ns]
# device             uint16
# ip                 uint32
# is_attributed      float64
# os                 uint16
# hour               uint8
# day                uint8
# n_channels         int64
# ip_app_count       int64
# ip_app_os_count    int64
# dtypes: datetime64[ns](2), float64(2), int64(3), uint16(4), uint32(1), uint8(2)
# memory usage: 14.8 GB

# %%
test = train[len_train:]
print('The size of the test set is ', len(test))

r = 0.1 # the fraction of the train data to be used for validation
val = train[(len_train-round(r*len_train)):len_train]
print('The size of the validation set is ', len(val))

train = train[:(len_train-round(r*len_train))]
print('The size of the train set is ', len(train))

target = 'is_attributed'
train[target] = train[target].astype('uint8')
train.info()

predictors = ['ip', 'device', 'app', 'os', 'channel', 'hour', 'n_channels', 'ip_app_count', 'ip_app_os_count']
categorical = ['ip', 'app', 'device', 'os', 'channel', 'hour']
gc.collect()
# Out:
# The size of the test set is  18790469
# The size of the validation set is  18490389
# The size of the train set is  166413501
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 166413501 entries, 0 to 166413500
# Data columns (total 14 columns):
# app                uint16
# attributed_time    datetime64[ns]
# channel            uint16
# click_id           float64
# click_time         datetime64[ns]
# device             uint16
# ip                 uint32
# is_attributed      uint8
# os                 uint16
# hour               uint8
# day                uint8
# n_channels         uint16
# ip_app_count       uint16
# ip_app_os_count    uint16
# dtypes: datetime64[ns](2), float64(1), uint16(7), uint32(1), uint8(3)
# memory usage: 8.2 GB
# 17

# %%
print("Preparing the datasets for training...")

params = {
    'boosting_type': 'gbdt',
    'objective': 'binary',
    'metric': 'auc',
    'learning_rate': 0.1,
    'num_leaves': 255,  
    'max_depth': 8,  
    'min_child_samples': 100,  
    'max_bin': 100,  
    'subsample': 0.7,  
    'subsample_freq': 1,  
    'colsample_bytree': 0.7,  
    'min_child_weight': 0,  
    'subsample_for_bin': 200000,  
    'min_split_gain': 0,  
    'reg_alpha': 0,  
    'reg_lambda': 0,  
   # 'nthread': 8,
    'verbose': 0,
    'scale_pos_weight':99 
    }
    
dtrain = lgb.Dataset(train[predictors].values, label=train[target].values,
                      feature_name=predictors,
                      categorical_feature=categorical
                      )
dvalid = lgb.Dataset(val[predictors].values, label=val[target].values,
                      feature_name=predictors,
                      categorical_feature=categorical
                      )
# Out:
# Preparing the datasets for training...

# %%
evals_results = {}

print("Training the model...")

lgb_model = lgb.train(params, 
                 dtrain, 
                 valid_sets=[dtrain, dvalid], 
                 valid_names=['train','valid'], 
                 evals_result=evals_results, 
                 num_boost_round=350,
                 early_stopping_rounds=30,
                 verbose_eval=True, 
                 feval=None)

del train
del val
gc.collect()
# Out:
# Training the model...
# /opt/conda/lib/python3.6/site-packages/lightgbm/basic.py:1036: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# /opt/conda/lib/python3.6/site-packages/lightgbm/basic.py:681: UserWarning: categorical_feature in param dict is overrided.
#   warnings.warn('categorical_feature in param dict is overrided.')
# [1]	train's auc: 0.941001	valid's auc: 0.94027
# Training until validation scores don't improve for 30 rounds.
# [2]	train's auc: 0.960152	valid's auc: 0.957416
# [3]	train's auc: 0.966549	valid's auc: 0.9642
# [4]	train's auc: 0.968111	valid's auc: 0.966882
# [5]	train's auc: 0.969138	valid's auc: 0.968428
# [6]	train's auc: 0.969609	valid's auc: 0.968831
# [7]	train's auc: 0.970116	valid's auc: 0.969378
# [8]	train's auc: 0.970055	valid's auc: 0.969044
# [9]	train's auc: 0.970572	valid's auc: 0.969754
# [10]	train's auc: 0.970964	valid's auc: 0.970297
# [11]	train's auc: 0.97128	valid's auc: 0.97062
# [12]	train's auc: 0.971518	valid's auc: 0.970929
# [13]	train's auc: 0.97177	valid's auc: 0.971008
# [14]	train's auc: 0.971549	valid's auc: 0.970554
# [15]	train's auc: 0.971605	valid's auc: 0.970617
# [16]	train's auc: 0.971847	valid's auc: 0.970821
# [17]	train's auc: 0.971897	valid's auc: 0.970894
# [18]	train's auc: 0.972192	valid's auc: 0.971095
# [19]	train's auc: 0.972424	valid's auc: 0.971447
# [20]	train's auc: 0.972676	valid's auc: 0.971826
# [21]	train's auc: 0.97277	valid's auc: 0.971772
# [22]	train's auc: 0.972977	valid's auc: 0.97205
# [23]	train's auc: 0.973512	valid's auc: 0.972256
# [24]	train's auc: 0.973711	valid's auc: 0.972505
# [25]	train's auc: 0.973991	valid's auc: 0.972485
# [26]	train's auc: 0.974107	valid's auc: 0.972531
# [27]	train's auc: 0.974325	valid's auc: 0.972574
# [28]	train's auc: 0.9746	valid's auc: 0.972667
# [29]	train's auc: 0.97482	valid's auc: 0.972861
# [30]	train's auc: 0.974982	valid's auc: 0.972924
# [31]	train's auc: 0.975144	valid's auc: 0.973025
# [32]	train's auc: 0.975298	valid's auc: 0.973
# [33]	train's auc: 0.975715	valid's auc: 0.973175
# [34]	train's auc: 0.976031	valid's auc: 0.973248
# [35]	train's auc: 0.976325	valid's auc: 0.97354
# [36]	train's auc: 0.976549	valid's auc: 0.973797
# [37]	train's auc: 0.976909	valid's auc: 0.973838
# [38]	train's auc: 0.977204	valid's auc: 0.973907
# [39]	train's auc: 0.977534	valid's auc: 0.97403
# [40]	train's auc: 0.977861	valid's auc: 0.974123
# [41]	train's auc: 0.978103	valid's auc: 0.974071
# [42]	train's auc: 0.978267	valid's auc: 0.97412
# [43]	train's auc: 0.978489	valid's auc: 0.974136
# [44]	train's auc: 0.978657	valid's auc: 0.974372
# [45]	train's auc: 0.978773	valid's auc: 0.974539
# [46]	train's auc: 0.978892	valid's auc: 0.97456
# [47]	train's auc: 0.979095	valid's auc: 0.974585
# [48]	train's auc: 0.979424	valid's auc: 0.974603
# [49]	train's auc: 0.979538	valid's auc: 0.974598
# [50]	train's auc: 0.979804	valid's auc: 0.97462
# [51]	train's auc: 0.979925	valid's auc: 0.97462
# [52]	train's auc: 0.980068	valid's auc: 0.974815
# [53]	train's auc: 0.980274	valid's auc: 0.974829
# [54]	train's auc: 0.980662	valid's auc: 0.974844
# [55]	train's auc: 0.980867	valid's auc: 0.974849
# [56]	train's auc: 0.980936	valid's auc: 0.974941
# [57]	train's auc: 0.981127	valid's auc: 0.974936
# [58]	train's auc: 0.981373	valid's auc: 0.974956
# [59]	train's auc: 0.981498	valid's auc: 0.975026
# [60]	train's auc: 0.98162	valid's auc: 0.975081
# [61]	train's auc: 0.981746	valid's auc: 0.975061
# [62]	train's auc: 0.98184	valid's auc: 0.97514
# [63]	train's auc: 0.981942	valid's auc: 0.975203
# [64]	train's auc: 0.982149	valid's auc: 0.975313
# [65]	train's auc: 0.982233	valid's auc: 0.975383
# [66]	train's auc: 0.982321	valid's auc: 0.975479
# [67]	train's auc: 0.982419	valid's auc: 0.975446
# [68]	train's auc: 0.982538	valid's auc: 0.975475
# [69]	train's auc: 0.982613	valid's auc: 0.975531
# [70]	train's auc: 0.982725	valid's auc: 0.975567
# [71]	train's auc: 0.982851	valid's auc: 0.97559
# [72]	train's auc: 0.982981	valid's auc: 0.975705
# [73]	train's auc: 0.983052	valid's auc: 0.975792
# [74]	train's auc: 0.983106	valid's auc: 0.975815
# [75]	train's auc: 0.983168	valid's auc: 0.97585
# [76]	train's auc: 0.983238	valid's auc: 0.975887
# [77]	train's auc: 0.983324	valid's auc: 0.975896
# [78]	train's auc: 0.983421	valid's auc: 0.975892
# [79]	train's auc: 0.983534	valid's auc: 0.975996
# [80]	train's auc: 0.983589	valid's auc: 0.976017
# [81]	train's auc: 0.983661	valid's auc: 0.976101
# [82]	train's auc: 0.983709	valid's auc: 0.976147
# [83]	train's auc: 0.983757	valid's auc: 0.976132
# [84]	train's auc: 0.9838	valid's auc: 0.976135
# [85]	train's auc: 0.983872	valid's auc: 0.976158
# [86]	train's auc: 0.983946	valid's auc: 0.976201
# [87]	train's auc: 0.984023	valid's auc: 0.976246
# [88]	train's auc: 0.984066	valid's auc: 0.976286
# [89]	train's auc: 0.984102	valid's auc: 0.976289
# [90]	train's auc: 0.984126	valid's auc: 0.976291
# [91]	train's auc: 0.9842	valid's auc: 0.976343
# [92]	train's auc: 0.984233	valid's auc: 0.976343
# [93]	train's auc: 0.984253	valid's auc: 0.97635
# [94]	train's auc: 0.984284	valid's auc: 0.976352
# [95]	train's auc: 0.984344	valid's auc: 0.976356
# [96]	train's auc: 0.984385	valid's auc: 0.976361
# [97]	train's auc: 0.984405	valid's auc: 0.97637
# [98]	train's auc: 0.984448	valid's auc: 0.976376
# [99]	train's auc: 0.984475	valid's auc: 0.976376
# [100]	train's auc: 0.984509	valid's auc: 0.976374
# [101]	train's auc: 0.98459	valid's auc: 0.976428
# [102]	train's auc: 0.98462	valid's auc: 0.97642
# [103]	train's auc: 0.984653	valid's auc: 0.976431
# [104]	train's auc: 0.984677	valid's auc: 0.976434
# [105]	train's auc: 0.984694	valid's auc: 0.976441
# [106]	train's auc: 0.984724	valid's auc: 0.976453
# [107]	train's auc: 0.984746	valid's auc: 0.97646
# [108]	train's auc: 0.984808	valid's auc: 0.976506
# [109]	train's auc: 0.984854	valid's auc: 0.976528
# [110]	train's auc: 0.984864	valid's auc: 0.976562
# [111]	train's auc: 0.984876	valid's auc: 0.976565
# [112]	train's auc: 0.984894	valid's auc: 0.976567
# [113]	train's auc: 0.984943	valid's auc: 0.976606
# [114]	train's auc: 0.984958	valid's auc: 0.976611
# [115]	train's auc: 0.984979	valid's auc: 0.976606
# [116]	train's auc: 0.985002	valid's auc: 0.9766
# [117]	train's auc: 0.985021	valid's auc: 0.976605
# [118]	train's auc: 0.985037	valid's auc: 0.97661
# [119]	train's auc: 0.985056	valid's auc: 0.976609
# [120]	train's auc: 0.985107	valid's auc: 0.976637
# [121]	train's auc: 0.98516	valid's auc: 0.976662
# [122]	train's auc: 0.985172	valid's auc: 0.976665
# [123]	train's auc: 0.985188	valid's auc: 0.976666
# [124]	train's auc: 0.985253	valid's auc: 0.976694
# [125]	train's auc: 0.985264	valid's auc: 0.9767
# [126]	train's auc: 0.985284	valid's auc: 0.976703
# [127]	train's auc: 0.985293	valid's auc: 0.976699
# [128]	train's auc: 0.985302	valid's auc: 0.976694
# [129]	train's auc: 0.985315	valid's auc: 0.976689
# [130]	train's auc: 0.985322	valid's auc: 0.97669
# [131]	train's auc: 0.985375	valid's auc: 0.976726
# [132]	train's auc: 0.98539	valid's auc: 0.976726
# [133]	train's auc: 0.985408	valid's auc: 0.976737
# [134]	train's auc: 0.985418	valid's auc: 0.976741
# [135]	train's auc: 0.985427	valid's auc: 0.976742
# [136]	train's auc: 0.985438	valid's auc: 0.976743
# [137]	train's auc: 0.985456	valid's auc: 0.97674
# [138]	train's auc: 0.985474	valid's auc: 0.976737
# [139]	train's auc: 0.985486	valid's auc: 0.97673
# [140]	train's auc: 0.98551	valid's auc: 0.976735
# [141]	train's auc: 0.985536	valid's auc: 0.976739
# [142]	train's auc: 0.985546	valid's auc: 0.976747
# [143]	train's auc: 0.985551	valid's auc: 0.976747
# [144]	train's auc: 0.985572	valid's auc: 0.97674
# [145]	train's auc: 0.985579	valid's auc: 0.976742
# [146]	train's auc: 0.985592	valid's auc: 0.976744
# [147]	train's auc: 0.985602	valid's auc: 0.976745
# [148]	train's auc: 0.985615	valid's auc: 0.976743
# [149]	train's auc: 0.985639	valid's auc: 0.976728
# [150]	train's auc: 0.985647	valid's auc: 0.976729
# [151]	train's auc: 0.985661	valid's auc: 0.976731
# [152]	train's auc: 0.985675	valid's auc: 0.976733
# [153]	train's auc: 0.985679	valid's auc: 0.976734
# [154]	train's auc: 0.985692	valid's auc: 0.976726
# [155]	train's auc: 0.985772	valid's auc: 0.976766
# [156]	train's auc: 0.985812	valid's auc: 0.976798
# [157]	train's auc: 0.985828	valid's auc: 0.976799
# [158]	train's auc: 0.985843	valid's auc: 0.976795
# [159]	train's auc: 0.985853	valid's auc: 0.976787
# [160]	train's auc: 0.985862	valid's auc: 0.976786
# [161]	train's auc: 0.985865	valid's auc: 0.976784
# [162]	train's auc: 0.985906	valid's auc: 0.976801
# [163]	train's auc: 0.985909	valid's auc: 0.976803
# [164]	train's auc: 0.985931	valid's auc: 0.976805
# [165]	train's auc: 0.985972	valid's auc: 0.97683
# [166]	train's auc: 0.985976	valid's auc: 0.976832
# [167]	train's auc: 0.985981	valid's auc: 0.976832
# [168]	train's auc: 0.98599	valid's auc: 0.976835
# [169]	train's auc: 0.985994	valid's auc: 0.976837
# [170]	train's auc: 0.986	valid's auc: 0.976844
# [171]	train's auc: 0.986004	valid's auc: 0.976843
# [172]	train's auc: 0.986013	valid's auc: 0.976842
# [173]	train's auc: 0.986016	valid's auc: 0.97684
# [174]	train's auc: 0.98602	valid's auc: 0.976842
# [175]	train's auc: 0.986032	valid's auc: 0.976839
# [176]	train's auc: 0.986072	valid's auc: 0.97685
# [177]	train's auc: 0.986079	valid's auc: 0.976849
# [178]	train's auc: 0.986084	valid's auc: 0.976846
# [179]	train's auc: 0.986087	valid's auc: 0.976848
# [180]	train's auc: 0.98609	valid's auc: 0.976847
# [181]	train's auc: 0.986095	valid's auc: 0.976845
# [182]	train's auc: 0.986097	valid's auc: 0.976847
# [183]	train's auc: 0.986105	valid's auc: 0.976845
# [184]	train's auc: 0.986109	valid's auc: 0.976847
# [185]	train's auc: 0.986111	valid's auc: 0.976842
# [186]	train's auc: 0.986148	valid's auc: 0.976831
# [187]	train's auc: 0.986162	valid's auc: 0.976826
# [188]	train's auc: 0.986167	valid's auc: 0.976824
# [189]	train's auc: 0.986212	valid's auc: 0.976858
# [190]	train's auc: 0.986215	valid's auc: 0.976856
# [191]	train's auc: 0.986235	valid's auc: 0.976861
# [192]	train's auc: 0.986272	valid's auc: 0.976875
# [193]	train's auc: 0.986276	valid's auc: 0.976872
# [194]	train's auc: 0.986278	valid's auc: 0.976871
# [195]	train's auc: 0.986312	valid's auc: 0.976878
# [196]	train's auc: 0.986317	valid's auc: 0.976878
# [197]	train's auc: 0.986319	valid's auc: 0.976878
# [198]	train's auc: 0.986324	valid's auc: 0.976873
# [199]	train's auc: 0.986327	valid's auc: 0.97687
# [200]	train's auc: 0.986389	valid's auc: 0.97688
# [201]	train's auc: 0.986432	valid's auc: 0.97691
# [202]	train's auc: 0.986435	valid's auc: 0.976908
# [203]	train's auc: 0.986437	valid's auc: 0.976912
# [204]	train's auc: 0.986441	valid's auc: 0.976913
# [205]	train's auc: 0.986477	valid's auc: 0.976944
# [206]	train's auc: 0.986507	valid's auc: 0.976962
# [207]	train's auc: 0.986512	valid's auc: 0.97696
# [208]	train's auc: 0.986515	valid's auc: 0.976961
# [209]	train's auc: 0.986517	valid's auc: 0.976954
# [210]	train's auc: 0.986542	valid's auc: 0.976948
# [211]	train's auc: 0.986545	valid's auc: 0.976945
# [212]	train's auc: 0.986549	valid's auc: 0.976944
# [213]	train's auc: 0.986551	valid's auc: 0.976942
# [214]	train's auc: 0.986591	valid's auc: 0.976953
# [215]	train's auc: 0.986635	valid's auc: 0.976952
# [216]	train's auc: 0.986667	valid's auc: 0.976962
# [217]	train's auc: 0.986671	valid's auc: 0.976961
# [218]	train's auc: 0.986674	valid's auc: 0.97696
# [219]	train's auc: 0.986678	valid's auc: 0.976955
# [220]	train's auc: 0.986681	valid's auc: 0.976959
# [221]	train's auc: 0.986684	valid's auc: 0.976959
# [222]	train's auc: 0.986702	valid's auc: 0.976973
# [223]	train's auc: 0.986705	valid's auc: 0.976969
# [224]	train's auc: 0.986708	valid's auc: 0.976969
# [225]	train's auc: 0.98671	valid's auc: 0.976967
# [226]	train's auc: 0.986713	valid's auc: 0.976966
# [227]	train's auc: 0.986717	valid's auc: 0.97697
# [228]	train's auc: 0.986721	valid's auc: 0.97697
# [229]	train's auc: 0.986725	valid's auc: 0.976971
# [230]	train's auc: 0.986739	valid's auc: 0.976975
# [231]	train's auc: 0.986743	valid's auc: 0.976976
# [232]	train's auc: 0.986748	valid's auc: 0.976978
# [233]	train's auc: 0.986752	valid's auc: 0.976975
# [234]	train's auc: 0.986756	valid's auc: 0.976971
# [235]	train's auc: 0.98676	valid's auc: 0.976969
# [236]	train's auc: 0.986786	valid's auc: 0.976971
# [237]	train's auc: 0.98682	valid's auc: 0.977001
# [238]	train's auc: 0.986854	valid's auc: 0.976998
# [239]	train's auc: 0.986878	valid's auc: 0.977017
# [240]	train's auc: 0.986882	valid's auc: 0.977019
# [241]	train's auc: 0.986905	valid's auc: 0.977019
# [242]	train's auc: 0.986923	valid's auc: 0.97703
# [243]	train's auc: 0.986926	valid's auc: 0.977033
# [244]	train's auc: 0.986929	valid's auc: 0.977033
# [245]	train's auc: 0.986933	valid's auc: 0.977033
# [246]	train's auc: 0.986936	valid's auc: 0.97703
# [247]	train's auc: 0.986939	valid's auc: 0.977025
# [248]	train's auc: 0.986942	valid's auc: 0.977026
# [249]	train's auc: 0.986962	valid's auc: 0.977029
# [250]	train's auc: 0.986965	valid's auc: 0.977028
# [251]	train's auc: 0.986993	valid's auc: 0.977018
# [252]	train's auc: 0.987006	valid's auc: 0.977018
# [253]	train's auc: 0.98701	valid's auc: 0.977017
# [254]	train's auc: 0.987013	valid's auc: 0.977015
# [255]	train's auc: 0.987035	valid's auc: 0.977034
# [256]	train's auc: 0.987039	valid's auc: 0.977034
# [257]	train's auc: 0.987042	valid's auc: 0.97703
# [258]	train's auc: 0.987045	valid's auc: 0.97703
# [259]	train's auc: 0.987075	valid's auc: 0.977036
# [260]	train's auc: 0.987079	valid's auc: 0.977032
# [261]	train's auc: 0.987083	valid's auc: 0.977032
# [262]	train's auc: 0.987087	valid's auc: 0.977029
# [263]	train's auc: 0.98709	valid's auc: 0.977028
# [264]	train's auc: 0.987095	valid's auc: 0.977029
# [265]	train's auc: 0.987097	valid's auc: 0.977028
# [266]	train's auc: 0.9871	valid's auc: 0.977026
# [267]	train's auc: 0.987103	valid's auc: 0.977024
# [268]	train's auc: 0.987106	valid's auc: 0.977022
# [269]	train's auc: 0.98711	valid's auc: 0.977023
# [270]	train's auc: 0.987145	valid's auc: 0.977042
# [271]	train's auc: 0.987147	valid's auc: 0.977041
# [272]	train's auc: 0.987174	valid's auc: 0.977052
# [273]	train's auc: 0.987189	valid's auc: 0.977053
# [274]	train's auc: 0.987192	valid's auc: 0.977053
# [275]	train's auc: 0.987197	valid's auc: 0.977049
# [276]	train's auc: 0.987199	valid's auc: 0.977047
# [277]	train's auc: 0.987227	valid's auc: 0.977059
# [278]	train's auc: 0.98723	valid's auc: 0.97706
# [279]	train's auc: 0.987261	valid's auc: 0.977062
# [280]	train's auc: 0.987283	valid's auc: 0.977073
# [281]	train's auc: 0.987286	valid's auc: 0.977065
# [282]	train's auc: 0.987316	valid's auc: 0.977066
# [283]	train's auc: 0.987318	valid's auc: 0.977067
# [284]	train's auc: 0.987341	valid's auc: 0.977084
# [285]	train's auc: 0.987344	valid's auc: 0.977081
# [286]	train's auc: 0.987348	valid's auc: 0.977078
# [287]	train's auc: 0.987351	valid's auc: 0.977074
# [288]	train's auc: 0.987355	valid's auc: 0.977073
# [289]	train's auc: 0.987387	valid's auc: 0.977067
# [290]	train's auc: 0.987397	valid's auc: 0.977076
# [291]	train's auc: 0.9874	valid's auc: 0.977075
# [292]	train's auc: 0.987402	valid's auc: 0.97707
# [293]	train's auc: 0.987405	valid's auc: 0.977071
# [294]	train's auc: 0.987409	valid's auc: 0.977073
# [295]	train's auc: 0.987412	valid's auc: 0.977072
# [296]	train's auc: 0.987417	valid's auc: 0.977072
# [297]	train's auc: 0.987454	valid's auc: 0.977081
# [298]	train's auc: 0.987476	valid's auc: 0.977079
# [299]	train's auc: 0.987479	valid's auc: 0.977077
# [300]	train's auc: 0.987482	valid's auc: 0.97708
# [301]	train's auc: 0.987498	valid's auc: 0.977091
# [302]	train's auc: 0.987499	valid's auc: 0.977089
# [303]	train's auc: 0.987502	valid's auc: 0.977088
# [304]	train's auc: 0.987526	valid's auc: 0.977111
# [305]	train's auc: 0.987528	valid's auc: 0.977108
# [306]	train's auc: 0.987551	valid's auc: 0.977125
# [307]	train's auc: 0.987557	valid's auc: 0.977127
# [308]	train's auc: 0.98756	valid's auc: 0.977124
# [309]	train's auc: 0.987562	valid's auc: 0.977122
# [310]	train's auc: 0.987565	valid's auc: 0.977117
# [311]	train's auc: 0.987569	valid's auc: 0.977116
# [312]	train's auc: 0.987592	valid's auc: 0.977127
# [313]	train's auc: 0.987596	valid's auc: 0.977125
# [314]	train's auc: 0.987599	valid's auc: 0.977124
# [315]	train's auc: 0.987623	valid's auc: 0.97714
# [316]	train's auc: 0.987625	valid's auc: 0.977142
# [317]	train's auc: 0.987649	valid's auc: 0.977144
# [318]	train's auc: 0.987665	valid's auc: 0.977154
# [319]	train's auc: 0.987668	valid's auc: 0.977153
# [320]	train's auc: 0.987672	valid's auc: 0.977155
# [321]	train's auc: 0.987674	valid's auc: 0.977154
# [322]	train's auc: 0.987678	valid's auc: 0.977152
# [323]	train's auc: 0.987681	valid's auc: 0.977153
# [324]	train's auc: 0.987704	valid's auc: 0.977153
# [325]	train's auc: 0.987707	valid's auc: 0.977155
# [326]	train's auc: 0.987711	valid's auc: 0.977154
# [327]	train's auc: 0.987715	valid's auc: 0.977149
# [328]	train's auc: 0.987717	valid's auc: 0.977147
# [329]	train's auc: 0.987744	valid's auc: 0.977148
# [330]	train's auc: 0.987746	valid's auc: 0.97715
# [331]	train's auc: 0.987749	valid's auc: 0.977145
# [332]	train's auc: 0.987752	valid's auc: 0.977143
# [333]	train's auc: 0.98778	valid's auc: 0.977159
# [334]	train's auc: 0.987782	valid's auc: 0.977162
# [335]	train's auc: 0.987785	valid's auc: 0.977164
# [336]	train's auc: 0.987787	valid's auc: 0.977163
# [337]	train's auc: 0.98779	valid's auc: 0.977163
# [338]	train's auc: 0.987803	valid's auc: 0.977157
# [339]	train's auc: 0.987808	valid's auc: 0.977155
# [340]	train's auc: 0.98781	valid's auc: 0.977152
# [341]	train's auc: 0.987834	valid's auc: 0.977151
# [342]	train's auc: 0.987845	valid's auc: 0.97716
# [343]	train's auc: 0.987847	valid's auc: 0.977157
# [344]	train's auc: 0.987853	valid's auc: 0.977155
# [345]	train's auc: 0.987877	valid's auc: 0.97716
# [346]	train's auc: 0.987894	valid's auc: 0.977159
# [347]	train's auc: 0.987898	valid's auc: 0.977158
# [348]	train's auc: 0.987923	valid's auc: 0.977148
# [349]	train's auc: 0.987936	valid's auc: 0.977144
# [350]	train's auc: 0.987962	valid's auc: 0.977139
# Did not meet early stopping. Best iteration is:
# [350]	train's auc: 0.987962	valid's auc: 0.977139
# 229

# %%
test.head()
# Out:
#            app attributed_time  channel  click_id          click_time  device  \
# 184903890    9             NaT      107       0.0 2017-11-10 04:00:00       1
# 184903891    9             NaT      466       1.0 2017-11-10 04:00:00       1
# 184903892   21             NaT      128       2.0 2017-11-10 04:00:00       1
# 184903893   15             NaT      111       3.0 2017-11-10 04:00:00       1
# 184903894   12             NaT      328       4.0 2017-11-10 04:00:00       1
#
#                ip  is_attributed  os  hour  day  n_channels  ip_app_count  \
# 184903890    5744            NaN   3     4   10          34           113
# 184903891  119901            NaN   3     4   10         403          2302
# 184903892   72287            NaN  19     4   10         229           701
# 184903893   78477            NaN  13     4   10         239           827
# 184903894  123080            NaN  13     4   10          60           205
#
#            ip_app_os_count
# 184903890                3
# 184903891               27
# 184903892              121
# 184903893              261
# 184903894               38

# %%
# Feature names:
print('Feature names:', lgb_model.feature_name())

# Feature importances:
print('Feature importances:', list(lgb_model.feature_importance()))

print("Preparing data for submission...")

submit = pd.read_csv('data/test.csv', dtype='int', usecols=['click_id'])

print("Predicting the submission data...")

submit['is_attributed'] = lgb_model.predict(test[predictors], num_iteration=lgb_model.best_iteration)

print("Writing the submission data into a csv file...")

submit.to_csv('output/submission.csv', index=False)

print("All done...")
# Out:
# Feature names: ['ip', 'device', 'app', 'os', 'channel', 'hour', 'n_channels', 'ip_app_count', 'ip_app_os_count']
# Feature importances: [3625, 527, 5433, 6333, 6751, 5952, 12066, 13853, 9855]
# Preparing data for submission...
# Predicting the submission data...
# Writing the submission data into a csv file...
# All done...
